# %% [markdown]
# #                    SJSU MOVIE DATABASE

# %% [markdown]
# ### Database host: data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com

# %% [markdown]
# #### user : admin
# #### password : Qwerty12# , database : sjsu_movie_db

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
import pandas as pd

# %% [markdown]
# ## Showing all databases

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_db = "show databases"
        cursor.execute(show_db)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Database']
        display(df)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3       sjsu_movie_db
# 4                 sys

# %% [markdown]
# ## Show tables

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "show tables"
        cursor.execute(show_table)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Tables']
        display(df)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#                       Tables
# 0         agent_availability
# 1                        log
# 2                      movie
# 3               movie_actors
# 4                movie_genre
# 5            profile_history
# 6            profile_my_list
# 7                   profiles
# 8   service_request_assigned
# 9       service_request_info
# 10              user_billing
# 11                     users

# %% [markdown]
# # Describe tables

# %% [markdown]
# ## 1. movie

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE movie"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('imdb_rank', b'int', 'NO', 'PRI', None, '')
# ('Title', b'text', 'YES', '', None, '')
# ('Description', b'text', 'YES', '', None, '')
# ('Director', b'text', 'YES', '', None, '')
# ('Year', b'int', 'YES', '', None, '')
# ('Runtime', b'int', 'YES', '', None, '')
# ('Rating', b'double', 'YES', '', None, '')
# ('Votes', b'int', 'YES', '', None, '')
# ('Revenue', b'double', 'YES', '', None, '')
# ('Metascore', b'int', 'YES', '', None, '')

# %% [markdown]
# ## 2. movie_actors

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE movie_actors"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('imdb_rank', b'int', 'NO', 'PRI', None, '')
# ('actor', b'varchar(100)', 'NO', 'PRI', None, '')

# %% [markdown]
# ## 3. movie_genre

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE movie_genre"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('imdb_rank', b'int', 'NO', 'PRI', None, '')
# ('genre', b'varchar(100)', 'NO', 'PRI', None, '')

# %% [markdown]
# ## 4. profiles

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE profiles"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('profile_name', b'varchar(50)', 'NO', 'PRI', None, '')
# ('emailid', b'varchar(255)', 'NO', 'PRI', None, '')
# ('service_id', b'int', 'NO', 'UNI', None, 'auto_increment')

# %% [markdown]
# ## 5. profile_history

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE profile_history"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('view_timestamp', b'datetime', 'NO', 'PRI', None, '')
# ('imdb_rank', b'int', 'NO', 'MUL', None, '')
# ('emailid', b'varchar(255)', 'NO', 'PRI', None, '')
# ('profile_name', b'varchar(50)', 'NO', 'PRI', None, '')

# %% [markdown]
# ## 6. profile_my_list

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE profile_my_list"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('imdb_rank', b'int', 'NO', 'PRI', None, '')
# ('emailid', b'varchar(255)', 'NO', 'PRI', None, '')
# ('profile_name', b'varchar(50)', 'NO', 'PRI', None, '')

# %% [markdown]
# ## 7. service_request_info

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE service_request_info"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('complaint_id', b'int', 'NO', 'PRI', None, 'auto_increment')
# ('service_id', b'int', 'NO', 'MUL', None, '')
# ('date_of_complaint', b'date', 'YES', '', None, '')
# ('complaint_description', b'text', 'YES', '', None, '')

# %% [markdown]
# ## 8. agent_availability

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE agent_availability"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('agent_name', b'varchar(100)', 'NO', 'PRI', None, '')
# ('availability', b'tinyint(1)', 'YES', '', b'0', '')

# %% [markdown]
# ## 9. service_request_assigned

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE service_request_assigned"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('complaint_id', b'int', 'NO', 'PRI', None, '')
# ('complaint_severity', b'varchar(10)', 'YES', '', None, '')
# ('service_agent_name', b'varchar(100)', 'YES', '', None, '')
# ('service_assignment_datetime', b'datetime', 'YES', '', None, '')

# %% [markdown]
# ## 10. users

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE users"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('emailid', b'varchar(255)', 'NO', 'PRI', None, '')
# ('phoneno', b'varchar(20)', 'YES', '', None, '')
# ('name', b'varchar(150)', 'YES', '', None, '')
# ('dob', b'date', 'YES', '', None, '')
# ('password', b'varchar(100)', 'YES', '', None, '')
# ('account_create_date', b'date', 'YES', '', None, '')
# ('no_of_profiles', b'int', 'YES', '', None, '')
# ('preferred_language', b'varchar(100)', 'YES', '', None, '')

# %% [markdown]
# ## 11. user_billing

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        show_table = "DESCRIBE user_billing"
        cursor.execute(show_table)
        for record in cursor:
            print(record)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# ('billing_id', b'int', 'NO', 'PRI', None, 'auto_increment')
# ('emailid', b'varchar(255)', 'YES', 'MUL', None, '')
# ('phoneno', b'varchar(50)', 'YES', '', None, '')
# ('payment_method', b'varchar(150)', 'YES', '', None, '')
# ('billing_date', b'date', 'YES', '', None, '')
# ('status', b'varchar(20)', 'YES', '', None, '')

# %% [markdown]
# # Query execution

# %% [markdown]
# ## 1. User views his information on Login
# ### Note: Input the user email and password

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    email = input("Enter the user emailid\t")
    password = input("Enter password")
    with connection.cursor() as cursor:
        show_table = "SELECT U.emailid, U.name, U.phoneno, U.dob, GROUP_CONCAT(P.profile_name) FROM users U JOIN profiles P ON U.emailid = P.emailid WHERE U.emailid = '{}';".format(email)
        cursor.execute(show_table)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Email','Name','Phoneno','DOB','Profile-names']
        display(df)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# Enter the user emailid	0xanBs5jgpDam@hotmail.com
# Enter passwordpasswordhjghghj
#                        Email          Name       Phoneno         DOB  \
# 0  0xanBs5jgpDam@hotmail.com  susan thomas  330-423-0403  1965-05-07
#
#   Profile-names
# 0         Jerin

# %% [markdown]
# ## 2. Viewing all the movies in a profiles's mylist

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        profile_movie_wishlist = """SELECT M.Title,
        GROUP_CONCAT(DISTINCT G.genre),
        M.Description,
        M.Director,
        GROUP_CONCAT(DISTINCT A.actor),
        M.Year,
        M.Runtime,
        M.Rating,
        M.Votes,
        M.Revenue
        FROM
            profile_my_list P
                JOIN
            movie M ON P.imdb_rank = M.imdb_rank
                JOIN
            movie_actors A ON M.imdb_rank = A.imdb_rank
                JOIN
            movie_genre G ON A.imdb_rank = G.imdb_rank
        WHERE
            P.emailid = 'lPP0eaNhyLA4@yahoo.com'
                AND P.profile_name = 'goya'
        GROUP BY M.imdb_rank;"""
        cursor.execute(profile_movie_wishlist)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Title','genre','Description','Director','actor','Year','Runtime','Rating','Votes','Revenue']
        display(df)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#                      Title                    genre  \
# 0  Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 1                Lowriders                    Drama
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  A young street artist in East Los Angeles is c...  Ricardo de Montreuil
#
#                                                actor  Year  Runtime  Rating  \
# 0  Bradley Cooper,Chris Pratt,Vin Diesel,Zoe Saldana  2014      121     8.1
# 1  Demián Bichir,Gabriel Chavarria,Theo Rossi,Ton...  2016       99     6.3
#
#     Votes  Revenue
# 0  757074   333.13
# 1     279     4.21

# %% [markdown]
# ## 3. Viewing all the service requests raised by a profile user

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        profile_service_requests = """SELECT
        complaint_id, date_of_complaint, complaint_description
        FROM service_request_info S
        JOIN profiles P ON P.service_id = S.service_id
        WHERE P.emailid = 'BHyROtaYxz2ix11@comcast.net'
        AND P.profile_name = 'Jerry';"""
        cursor.execute(profile_service_requests)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['complaint_id', 'date_of_complaint', 'complaint_description']
        display(df)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#    complaint_id date_of_complaint  \
# 0        100008        2022-01-10
# 1        100088        2022-02-20
#
#                                complaint_description
# 0  Problems with the maturity rating or classific...
# 1  Problems with the maturity rating or classific...

# %% [markdown]
# ## 4. Showing all the deactivated users

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        deactivated_users = """ SELECT 
        B.emailid,
        U.name,
        B.phoneno,
        B.billing_date AS 'Last Bill Date'
        FROM
            user_billing B
                JOIN
            users U ON B.emailid = U.emailid
        WHERE
        status = 'Deactivated';"""
        cursor.execute(deactivated_users)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['emailid','name','phoneno','Last Bill Date']
        display(df)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#                             emailid               name       phoneno  \
# 0                   qmdV2@yahoo.com     robert johnson  512-972-5037
# 1   fueuQf36qjE7wPEybhO@hotmail.com       james martin  512-972-5049
# 2        l0JVAxCdS6VYbfGu@gmail.com   patricia johnson  512-974-7676
# 3            LKfOQfyfDlK1aw@msn.com       david martin  404-491-7274
# 4          PyaMKujXFolfIy3t@msn.com     michael garcia  774-204-6255
# 5                       7aW@msn.com      joseph miller  312-291-4832
# 6             IRNNPa5wt@hotmail.com     richard wilson  307-620-0678
# 7                  Ynf3@hotmail.com         daniel lee  757-296-9817
# 8                 CmSOUuF@yahoo.com  jennifer thompson  561-965-9235
# 9                   dH1Mt@gmail.com    elizabeth moore  803-619-6014
# 10                    HthH3@aol.com      elizabeth lee  415-236-3604
# 11         yB3tB1BkKJK1@hotmail.com    susan rodriguez  781-298-2820
#
#    Last Bill Date
# 0      2019-03-22
# 1      2019-03-01
# ...

# %% [markdown]
# ## 5. Top 10 most watched movies

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        deactivated_users = """ SELECT 
        M.Title
        FROM
        movie M
        INNER JOIN (SELECT 
            P.imdb_rank
            FROM
            profile_history P
        GROUP BY P.imdb_rank
        ORDER BY COUNT(*) DESC
        LIMIT 10) AS PP
        ON M.imdb_rank = PP.imdb_rank;"""
        cursor.execute(deactivated_users)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Most Watched Movies']
        display(df)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#                 Most Watched Movies
# 0           Guardians of the Galaxy
# 1                    Hounds of Love
# 2  Resident Evil: The Final Chapter
# 3                            Trolls
# 4                      Patriots Day
# 5                        Prometheus
# 6                     Suicide Squad
# 7           Don't Fuck in the Woods
# 8                         Rogue One
# 9                           Silence

# %%
from matplotlib import pyplot as plt

connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        x = """ SELECT 
        M.Title,
        PP.cnt
        FROM
        movie M
        INNER JOIN (SELECT 
            imdb_rank,
            count(1) as cnt
            FROM
            profile_history 
        GROUP BY imdb_rank)PP
        ON M.imdb_rank = PP.imdb_rank ORDER BY PP.cnt DESC;"""
        cursor.execute(x)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Most Watched Movies','Count']
        df.set_index('Most Watched Movies', inplace=True)
        
        df.head(10).plot(kind="bar")
        
        plt.title("Top Watched Movies")
        plt.xlabel("Movie names")
        plt.ylabel("No. of times watched")
        
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()

# %% [markdown]
# ## 6. Most watched hour

# %%
from matplotlib import pyplot as plt

connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        high_hour = """SELECT 
    hour, COUNT(1) AS cnt
FROM
    (SELECT 
        HOUR(view_timestamp) AS hour
    FROM
        profile_history) a
GROUP BY hour;
        """
        cursor.execute(high_hour)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Hour','Count']
        df.set_index('Hour', inplace=True)
        df.head(5).plot(kind="bar")
        
        plt.title("Most watched hour in a day")
        plt.xlabel("Hour")
        plt.ylabel("Count")
        
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()

# %% [markdown]
# ## 7. Most Anticipated actor based on profile My list feature

# %%
from matplotlib import pyplot as plt

connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        anticipated_actor = """SELECT *
FROM
    (SELECT 
        actor,COUNT(1) AS cnt
    FROM
        (SELECT 
        actor
    FROM
        profile_my_list a
    JOIN movie_actors b ON a.imdb_rank = b.imdb_rank) x
    GROUP BY actor) y
ORDER BY cnt DESC;
        """
        cursor.execute(anticipated_actor)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['actor_anticipated','count']
        df.set_index('actor_anticipated', inplace=True)
        
        #display(df.head(5))
        
        df.head(5).plot.pie(y='count', figsize=(5, 5))
        plt.title("Most anticipated actor")
        
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()

# %% [markdown]
# ## 8. Actors who have performed in more than 1 movie

# %%
connection =connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        anticipated_actor = """SELECT 
        COUNT(1) AS no_of_movies, actor
    FROM
        movie_actors
    GROUP BY actor ORDER BY no_of_movies DESC;
        """
        cursor.execute(anticipated_actor)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Number of movies acted','Actor']
        display(df.head(20))
        
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#     Number of movies acted                Actor
# 0                       15        Mark Wahlberg
# 1                       14         Hugh Jackman
# 2                       13       Christian Bale
# 3                       13            Brad Pitt
# 4                       12   Michael Fassbender
# 5                       12   Scarlett Johansson
# 6                       12        Anne Hathaway
# 7                       12    Robert Downey Jr.
# 8                       12          Johnny Depp
# 9                       12            Tom Hardy
# 10                      12       Channing Tatum
# 11                      11       Bradley Cooper
# 12                      11    Jennifer Lawrence
# 13                      11      Jake Gyllenhaal
# 14                      11        Gerard Butler
# 15                      11       Cate Blanchett
# 16                      11         Shia LaBeouf
# 17                      11   Chloë Grace Moretz
# 18                      10      Charlize Theron
# ...

# %% [markdown]
# ## 9. Daily service request counts

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        anticipated_actor = """SELECT 
        COUNT(complaint_id) AS no_of_complaints, date_of_complaint
    FROM
        service_request_info
    GROUP BY date_of_complaint ORDER BY no_of_complaints DESC;
        """
        cursor.execute(anticipated_actor)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['no_of_complaints','date_of_complaint']
        display(df.head(10))
        
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#    no_of_complaints date_of_complaint
# 0                 5        2022-02-17
# 1                 5        2022-02-18
# 2                 5        2022-02-19
# 3                 5        2022-02-22
# 4                 5        2022-02-23
# 5                 4        2022-02-20
# 6                 4        2022-02-21
# 7                 3        2022-02-11
# 8                 3        2022-02-16
# 9                 3        2022-02-15

# %% [markdown]
# ## 10. Most common type of complaint

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        anticipated_actor = """SELECT 
    *
FROM
    (SELECT 
        COUNT(1) AS count_complaint_type, complaint_description
    FROM
        service_request_info
    GROUP BY complaint_description) y
WHERE
    count_complaint_type = (SELECT 
            MAX(count_complaint_type) AS max_no_of_complaint
        FROM
            (SELECT 
                COUNT(1) AS count_complaint_type, complaint_description
            FROM
                service_request_info
            GROUP BY complaint_description) x);
        """
        cursor.execute(anticipated_actor)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['count_of_complaint','complaint_description']
        display(df)
        
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#    count_of_complaint             complaint_description
# 0                  42  Episodes or seasons out of order

# %% [markdown]
# ## 11. Most repeated movie from my lists

# %%
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        anticipated_actor = """SELECT 
    title, max_repetition
FROM
    (SELECT 
        MAX(count_of_movie_found) AS max_repetition, imdb_rank
    FROM
        (SELECT 
        COUNT(1) AS count_of_movie_found, imdb_rank
    FROM
        profile_my_list
    GROUP BY imdb_rank
    ORDER BY count_of_movie_found DESC) x) a
        JOIN
    movie b ON a.imdb_rank = b.imdb_rank;
        """
        cursor.execute(anticipated_actor)
        df = pd.DataFrame(cursor.fetchall())
        df.columns = ['Movie Title', 'Number of profile who added this movie']
        display(df)
        
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#       Movie Title  Number of profile who added this movie
# 0  Hounds of Love                                      20

# %% [markdown]
# # Access Privileges

# %% [markdown]
# ### Created a sjsu movie database user
#
# #### user: nikitha
# #### password: nikitha1234
#
# The sjsu movie database user has privileges on the following tables:
# 1. movie - select
# 2. movie_actors - select
# 3. movie_genre - select
# 4. profile - select, insert, update, delete
# 5. profile_history - select, insert
# 6. profile_my_list - select, insert, update, delete

# %%
#This will work because of the privilege
connection = connect(user='nikitha', password='nikitha1234', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        read_only = "select * from movie"
        cursor.execute(read_only)
        df = pd.DataFrame(cursor.fetchall())
        display(df.head(10))
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
#     0                        1  \
# 0   1  Guardians of the Galaxy
# 1   2               Prometheus
# 2   3                    Split
# 3   4                     Sing
# 4   5            Suicide Squad
# 5   6           The Great Wall
# 6   7               La La Land
# 7   8                 Mindhorn
# 8   9       The Lost City of Z
# 9  10               Passengers
#
#                                                    2                     3  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
# 5  European mercenaries searching for black powde...           Yimou Zhang
# 6  A jazz pianist falls for an aspiring actress i...       Damien Chazelle
# ...

# %%
#This will not work because of no privilege
connection = connect(user='nikitha', password='nikitha1234', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    with connection.cursor() as cursor:
        read_only = "select * from service_request_info"
        cursor.execute(read_only)
        df = pd.DataFrame(cursor.fetchall())
        display(df.head(1))
        
#except Exception as e:
#    print(e)
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
finally:
    connection.close()
# Out:
# Something went wrong: 1142 (42000): SELECT command denied to user 'nikitha'@'c-98-207-108-22.hsd1.ca.comcast.net' for table 'service_request_info'

# %% [markdown]
# ## Calling stored procedures

# %% [markdown]
# ### Procedure call to subscribe a new user

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    email = input("Enter the user emailid\t")
    name = input("Enter the user full name\t")
    phone = input("Enter the phone\t")
    password = input("Enter the password\t")
    dob = input("Enter the DOB\t")
    language = input("Enter the preferred language\t")
    with connection.cursor() as cursor:
        query = ("CALL create_user(%s, %s, %s, %s, %s, %s)")
        cursor.execute(query, (email,name,phone,password,dob,language))
        connection.commit();
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();

# %% [markdown]
# ### Procedure call to create a new profile in the existing user

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    email = input("Enter the user emailid\t")
    name = input("Enter the user profile name\t")
    with connection.cursor() as cursor:
        query = ("CALL create_profile(%s, %s)")
        cursor.execute(query, (email,name))
        connection.commit();
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();

# %% [markdown]
# ### Procedure call to store a movie a profile wants to watch by storing in profile my list

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    movie = input("Enter the Movie name\t")
    email = input("Enter the user emailid\t")
    name = input("Enter the user profile name\t")
    with connection.cursor() as cursor:
        query = ("CALL add_profile_movies(%s, %s, %s)")
        cursor.execute(query, (movie,email,name))
        connection.commit();
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();

# %% [markdown]
# ### Procedure call to added watched movie to profile history

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    movie = input("Enter the Movie name\t")
    email = input("Enter the user emailid\t")
    name = input("Enter the user profile name\t")
    with connection.cursor() as cursor:
        query = ("CALL add_profile_history(%s, %s, %s)")
        cursor.execute(query, (movie,email,name))
        connection.commit();
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();

# %% [markdown]
# ### Procedure call to create a new service request

# %%
from mysql.connector import connect, Error
connection = connect(user='admin', password='Qwerty12#', database='sjsu_movie_db', host='data-225-lab-1.czdgeus7ajgk.us-west-1.rds.amazonaws.com')

try:
    service_id = input("Enter the ServiceId\t")
    desc = input("Please describe the issue\t")
    with connection.cursor() as cursor:
        query = ("CALL createServiceRequest(%s, %s)")
        cursor.execute(query, (service_id,desc))
        connection.commit();
except mysql.connector.Error as err:
    print("Something went wrong: {}".format(err))
    with connection.cursor() as cursor:
        query = ("CALL log_error(%s, %s, %s)")
        cursor.execute(query, (err.errno, err.sqlstate, err.msg))
    connection.commit();
